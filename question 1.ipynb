# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("C:/Users/lasya/Downloads/archive (4).zip")

# %%
df.isnull().sum()
# Out:
# Company             0
# Amount              0
# Lead investors     26
# Valuation         124
# Industry            0
# Date reported       0
# dtype: int64

# %%
df.head(10)
# Out:
#              Company           Amount  \
# 0             OpenAI  $10,000,000,000
# 1             Stripe   $6,500,000,000
# 2      Inflection AI   $1,300,000,000
# 3          Anthropic   $1,250,000,000
# 4   Generate Capital   $1,030,900,000
# 5  Redwood Materials   $1,000,000,000
# 6           Stack AV   $1,000,000,000
# 7          SandboxAQ     $500,000,000
# 8             Lessen     $500,000,000
# 9           Rippling     $500,000,000
#
#                                       Lead investors        Valuation  \
# 0                                          Microsoft              NaN
# 1                                                NaN  $50,000,000,000
# 2  Microsoft, Reid Hoffman, Bill Gates, Eric Schm...   $4,000,000,000
# 3                                             Amazon   $4,000,000,000
# 4                                                NaN              NaN
# 5  Goldman Sachs Asset Management, Capricorn's Te...              NaN
# ...

# %%
df.describe()
# Out:
#           Company        Amount       Lead investors       Valuation Industry  \
# count         171           171                  145              47      171
# unique        161            69                  133              29       63
# top     Anthropic  $100,000,000  Andreessen Horowitz  $1,000,000,000  Biotech
# freq            4            41                    3               9       42
#
#        Date reported
# count            171
# unique            97
# top          8/23/23
# freq               5

# %%
df.shape
# Out:
# (171, 6)

# %%
df.tail()
# Out:
#            Company        Amount                  Lead investors  \
# 166      Inceptive  $100,000,000  NVentures, Andreessen Horowitz
# 167  Vesper Energy  $100,000,000                   GCM Grosvenor
# 168         Writer  $100,000,000                   Iconiq Growth
# 169          Pryon  $100,000,000   US Innovative Technology Fund
# 170         Openly  $100,000,000            Eden Global Partners
#
#         Valuation                 Industry Date reported
# 166           NaN                  Biotech        9/7/23
# 167           NaN                   Energy       9/13/23
# 168  $500,000,000  Artificial intelligence       9/18/23
# 169  $625,000,000  Artificial intelligence       9/19/23
# 170           NaN                Insurance       9/21/23

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Company         171 non-null    object
#  1   Amount          171 non-null    object
#  2   Lead investors  145 non-null    object
#  3   Valuation       47 non-null     object
#  4   Industry        171 non-null    object
#  5   Date reported   171 non-null    object
# dtypes: object(6)
# memory usage: 8.1+ KB

# %%
df.loc[0]
# Out:
# Company                            OpenAI
# Amount                    $10,000,000,000
# Lead investors                  Microsoft
# Valuation                             NaN
# Industry          Artificial intelligence
# Date reported                     1/23/23
# Name: 0, dtype: object

# %%
df.iloc[0,0]
# Out:
# 'OpenAI'

# %%
df.iloc[[3,4]]
# Out:
#             Company          Amount Lead investors       Valuation  \
# 3         Anthropic  $1,250,000,000         Amazon  $4,000,000,000
# 4  Generate Capital  $1,030,900,000            NaN             NaN
#
#                   Industry Date reported
# 3  Artificial intelligence       9/25/23
# 4                   Energy        1/6/23

# %%
x=df.iloc[:,:-1]
x
# Out:
#               Company           Amount  \
# 0              OpenAI  $10,000,000,000
# 1              Stripe   $6,500,000,000
# 2       Inflection AI   $1,300,000,000
# 3           Anthropic   $1,250,000,000
# 4    Generate Capital   $1,030,900,000
# ..                ...              ...
# 166         Inceptive     $100,000,000
# 167     Vesper Energy     $100,000,000
# 168            Writer     $100,000,000
# 169             Pryon     $100,000,000
# 170            Openly     $100,000,000
#
#                                         Lead investors        Valuation  \
# 0                                            Microsoft              NaN
# 1                                                  NaN  $50,000,000,000
# 2    Microsoft, Reid Hoffman, Bill Gates, Eric Schm...   $4,000,000,000
# 3                                               Amazon   $4,000,000,000
# 4                                                  NaN              NaN
# ...

# %%
y=df.iloc[:,:-1]
y
# Out:
#               Company           Amount  \
# 0              OpenAI  $10,000,000,000
# 1              Stripe   $6,500,000,000
# 2       Inflection AI   $1,300,000,000
# 3           Anthropic   $1,250,000,000
# 4    Generate Capital   $1,030,900,000
# ..                ...              ...
# 166         Inceptive     $100,000,000
# 167     Vesper Energy     $100,000,000
# 168            Writer     $100,000,000
# 169             Pryon     $100,000,000
# 170            Openly     $100,000,000
#
#                                         Lead investors        Valuation  \
# 0                                            Microsoft              NaN
# 1                                                  NaN  $50,000,000,000
# 2    Microsoft, Reid Hoffman, Bill Gates, Eric Schm...   $4,000,000,000
# 3                                               Amazon   $4,000,000,000
# 4                                                  NaN              NaN
# ...

# %%
df2=df.dropna(thresh = 3)

# %%
df.columns
# Out:
# Index(['Company', 'Amount', 'Lead investors', 'Valuation', 'Industry',
#        'Date reported'],
#       dtype='object')

# %%
df.isin(['?']).sum()
# Out:
# Company           0
# Amount            0
# Lead investors    0
# Valuation         0
# Industry          0
# Date reported     0
# dtype: int64

# %%
df=df.drop_duplicates()
